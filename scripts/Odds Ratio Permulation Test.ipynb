# %%
import os
import sys

# Make src importable whether cwd is repo root or scripts/
cwd = os.getcwd()
if os.path.basename(cwd) == "scripts":
    repo_root = os.path.abspath(os.path.join(cwd, ".."))
else:
    repo_root = cwd

src_path = os.path.join(repo_root, "src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

print(f"Using src path: {src_path}")

# Import the module from src/
import odds_ratio_test as ort
# Out:
# Using src path: /Users/calvin/orb-selection/src

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
loss_lt_49_95 = ort.odds_ratio_test(
    test="loss",
    occupancy_threshold=49,
    max_occ=95,
    alternative="LT",
    species_of_interest="Uloborus_diversus",
    results_dir=f"results/odds_ratio_test",
    fg_name='orbweavers',
    bg_name='non-orbweavers',
)
# Out:
# 98 species total, 44 foreground, 54 background
# First permulated tip values (species -> value):
# {'Tekellina_sadamotoi': 0.0, 'Robertus_nojimai': 0.0, 'Latrodectus_hasseltii': 0.0, 'Steatoda_grossa': 0.0, 'Rhomphaea_labiata': 0.0, 'Argyrodes_flavescens': 0.0, 'Argyrodes_miniaceus': 0.0, 'Cryptachaea_gigantipes': 0.0, 'Parasteatoda_culicivora': 0.0, 'Chrysso_octomaculata': 0.0, 'Theridion_varians': 0.0, 'Metleucauge_yunohamensis': 0.0, 'Mesida_sp_IDV5268': 0.0, 'Leucauge_dromedari': 0.0, 'Tetragnatha_yesoensis': 1.0, 'Tetragnatha_vermiformis': 1.0, 'Tetragnatha_mandibulata': 1.0, 'Tetragnatha_maxillosa': 1.0, 'Tetragnatha_extensa': 0.0, 'Tetragnatha_filiciphilia': 1.0, 'Tetragnatha_paludicola': 1.0, 'Tetragnatha_stelarobusta': 1.0, 'Tetragnatha_quasimodo': 1.0, 'Tetragnatha_waikamoi': 1.0, 'Tetragnatha_brevignatha': 1.0, 'Phonognatha_graeffei': 0.0, 'Caerostris_darwini': 1.0, 'Caerostris_extrusa': 1.0, 'Araneus_inustus': 1.0, 'Cyrtophora_cicatrosa': 1.0, 'Argiope_bruennichi': 1.0, 'Argiope_aetheroides': 1.0, 'Argiope_keyserlingi': 1.0, 'Metazygia_zilloides': 1.0, 'Acrosomoides_sp_IDV7426': 1.0, 'Dolophones_sp_IDV6683': 1.0, 'Backobourkia_brouni': 1.0, 'Cyclosa_octotuberculata': 1.0, 'Plebs_sachalinensis': 1.0, 'Eriophora_pustulosa': 1.0, 'Acroaspis_sp_IDV6688': 1.0, 'Neoscona_scylla': 1.0, 'Neoscona_subpullata': 1.0, 'Neoscona_theisi': 1.0, 'Neoscona_nautica': 1.0, 'Neoscona_adianta': 1.0, 'Ordgarius_hobsoni': 1.0, 'Ordgarius_sexspinosus': 1.0, 'Cyrtarachne_bufo': 1.0, 'Poecilopachys_australasia': 1.0, 'Hypsosinga_pygmaea': 1.0, 'Larinioides_cornutus': 1.0, 'Nuctenea_umbratica': 1.0, 'Larinia_phthisica': 1.0, 'Lariniaria_argiopiformis': 1.0, 'Microbathyphantes_tateyamaensis': 0.0, 'Neriene_oidedicata': 0.0, 'Neriene_clathrata': 0.0, 'Doenitzius_peniculus': 0.0, 'Doenitzius_pruvus': 0.0, 'Saaristoa_nipponica': 0.0, 'Floronia_bucculenta': 0.0, 'Drapetisca_socialis': 0.0, 'Syedra_oii': 0.0, 'Arcuphantes_tamaensis': 0.0, 'Arcuphantes_uenoi': 0.0, 'Arcuphantes_paiki': 0.0, 'Ryojius_japonicus': 0.0, 'Pseudomicrargus_latitegulatus': 0.0, 'Saitonia_ojiroensis': 0.0, 'Hypselistes_asiaticus': 0.0, 'Baryphymula_kamakuraensis': 0.0, 'Ainerigone_saitoi': 0.0, 'Gnathonarium_exsiccatum': 0.0, 'Ummeliata_osakaensis': 0.0, 'Ambicodamus_IDV6680': 0.0, 'Uloborus_diversus': 0.0, 'Deinopis_sp_IDV6783': 0.0, 'Deinopis_sp_IDV7365': 0.0, 'Desis_marina': 1.0, 'Neoantistea_quelpartensis': 1.0, 'Paratheuma_awasensis': 1.0, 'Pharta_brevipalpus': 1.0, 'Stephanopis_cambridgei': 0.0, 'Oxytate_striatipes': 0.0, 'Lehtinelagia_evanida': 1.0, 'Ozyptila_nongae': 0.0, 'Diaea_subdola': 0.0, 'Ebrechtella_tricuspidata': 0.0, 'Psechrus_IDV5238': 0.0, 'Pardosa_graminea': 0.0, 'Piratula_tanakai': 0.0, 'Zelotes_iriomotensis': 0.0, 'Clubiona_robusta': 0.0, 'Phrurolithus_coreanus': 0.0, 'Helpis_minitabunda': 0.0, 'Stertinius_kumadai': 0.0, 'Neon_minutus': 0.0}
# /Users/calvin/orb-selection/src/odds_ratio_test.py:199: RuntimeWarning: invalid value encountered in log
#   return -np.nansum(np.log(p), axis=0)
# Mean: -0.65, Stddev: 1.53, Count: 5393
# Optimized triple Gaussian parameters: [ 0.26486952 -2.16879357  1.00437189  0.4593986  -0.44994205  0.94457479
#   0.48526865  1.55623524]
#
# LAUNCHING PERMUTATION TEST
#
# ** Maximum occupancy set to 95 **
#
# ** Minimum occupancy set to 49 **
#
# Using 10000 permulation-derived foreground/background
# assignments (from simulated trees) instead of random assignment.
#
# Counting permuted distributions in which statistics
# derived from permulation-derived test groups are SMALLER
# than the true distribution's statistics (left-tailed)...
# 100%|██████████| 10000/10000 [1:27:32<00:00,  1.90it/s]
# Permutation counter for MEAN (single Gaussian): 1859
#
# Permutation counter for MEAN 1 (triple Gaussian): 733
#
# Permutation counter for MEAN 2 (triple Gaussian): 2453
#
# Permutation counter for MEAN 3 (triple Gaussian): 1278
#
# Filtering log odds ratio results df for occupancy >= 49, <= 95
# and log odds ratio threshold [-2.31810009  2.281341  ]
#
# Filtering for presence of Uloborus_diversus
#
# *********************** RESULTS ***********************
#
# Permutation test with 10000 repetitions for loss (left-tailed)
# with minimum occupancy *49* and maximum occupancy *95*
# Analysis run on 2026-03-23 at 18:24:23
# Foreground list: /Users/calvin/orb-selection/assets/orbweavers-list.txt
# Gene count file: /Users/calvin/orb-selection/assets/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/assets/N5.tsv
#
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 5393
# Total species: 98
# Foreground count: 44
# Background count: 54
# True mean: -0.6456648152761234
# True standard deviation: 1.5255396130376273
#
# ** PERMUTATION P-VALUES **
#
# Probability that the null is true for MEAN (single Gaussian): 0.1859
# Probability that the null is true for MEAN 1 (triple Gaussian): 0.0733
# Probability that the null is true for MEAN 2 (triple Gaussian): 0.2453
# Probability that the null is true for MEAN 3 (triple Gaussian): 0.1278
#
# permuted average mean: -0.018379545408871684
# permuted average standard deviation: 1.3981308168174822
# User-defined significance threshold: 0.05
# Permutation-derived alpha threshold: [-2.31810009  2.281341  ]
#
# Total HOGs with significantly different LORs between
# foreground and background (two-tailed): 908
#
# Total HOGs with significantly different LORs between
# foreground and background (two-tailed, Uloborus_diversus present): 616
#
# *********************** RESULTS ***********************
#
# Permutation test with 10000 repetitions for loss (left-tailed)
# with minimum occupancy *49* and maximum occupancy *95*
# Analysis run on 2026-03-23 at 18:24:23
# Foreground list: /Users/calvin/orb-selection/assets/orbweavers-list.txt
# Gene count file: /Users/calvin/orb-selection/assets/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/assets/N5.tsv
#
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 5393
# Total species: 98
# Foreground count: 44
# Background count: 54
# True mean: -0.6456648152761234
# True standard deviation: 1.5255396130376273
#
# ** PERMUTATION P-VALUES **
#
# Probability that the null is true for MEAN (single Gaussian): 0.1859
# Probability that the null is true for MEAN 1 (triple Gaussian): 0.0733
# Probability that the null is true for MEAN 2 (triple Gaussian): 0.2453
# Probability that the null is true for MEAN 3 (triple Gaussian): 0.1278
#
# permuted average mean: -0.018379545408871684
# permuted average standard deviation: 1.3981308168174822
# User-defined significance threshold: 0.05
# Permutation-derived alpha threshold: [-2.31810009  2.281341  ]
#
# Total HOGs with significantly different LORs between
# foreground and background (two-tailed): 908
#
# Total HOGs with significantly different LORs between
# foreground and background (two-tailed, Uloborus_diversus present): 616
#
# Results files saved to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Mar23/Run1_Loss_LT_49-95_10000x
#
# Files include:
# 	 1. [test]_permutation_results.png: True LORs distribution
# 		vs. average permuted distribution
# 	 2. [test]_permutation_stats_dists.png: Histograms of the
# 		means, standard deviations, and skews of all 10,000
# 		permuted LOR distributions
# 	 3. [test]_results_summary.txt: Text file summarizing results
# 	 4. [test].pkl: Pickle file storing the BoostrapTestResults
# 		instance generated by this analysis
# 	 5. [test]_[species]_fltrd_permutation_hits.csv: Results table
# 		filtered for occupancy, species of interest (if specified),
# 		and surpassing permutation-derived significance thresholds
# 	 6. All odds and log odds ratios (not filtered for occupancy,
# 		species, or significance)

# %%
dup_rt_49_98 = ort.odds_ratio_test(
    test="duplication",
    occupancy_threshold=49,
    alternative="RT",
    species_of_interest="Uloborus_diversus",
    results_dir=f"results/odds_ratio_test",
    fg_name='orbweavers',
    bg_name='non-orbweavers',
)
# Out:
# 98 species total, 44 foreground, 54 background
# First permulated tip values (species -> value):
# {'Tekellina_sadamotoi': 0.0, 'Robertus_nojimai': 0.0, 'Latrodectus_hasseltii': 0.0, 'Steatoda_grossa': 0.0, 'Rhomphaea_labiata': 0.0, 'Argyrodes_flavescens': 0.0, 'Argyrodes_miniaceus': 0.0, 'Cryptachaea_gigantipes': 0.0, 'Parasteatoda_culicivora': 0.0, 'Chrysso_octomaculata': 0.0, 'Theridion_varians': 0.0, 'Metleucauge_yunohamensis': 0.0, 'Mesida_sp_IDV5268': 0.0, 'Leucauge_dromedari': 0.0, 'Tetragnatha_yesoensis': 1.0, 'Tetragnatha_vermiformis': 1.0, 'Tetragnatha_mandibulata': 1.0, 'Tetragnatha_maxillosa': 1.0, 'Tetragnatha_extensa': 0.0, 'Tetragnatha_filiciphilia': 1.0, 'Tetragnatha_paludicola': 1.0, 'Tetragnatha_stelarobusta': 1.0, 'Tetragnatha_quasimodo': 1.0, 'Tetragnatha_waikamoi': 1.0, 'Tetragnatha_brevignatha': 1.0, 'Phonognatha_graeffei': 0.0, 'Caerostris_darwini': 1.0, 'Caerostris_extrusa': 1.0, 'Araneus_inustus': 1.0, 'Cyrtophora_cicatrosa': 1.0, 'Argiope_bruennichi': 1.0, 'Argiope_aetheroides': 1.0, 'Argiope_keyserlingi': 1.0, 'Metazygia_zilloides': 1.0, 'Acrosomoides_sp_IDV7426': 1.0, 'Dolophones_sp_IDV6683': 1.0, 'Backobourkia_brouni': 1.0, 'Cyclosa_octotuberculata': 1.0, 'Plebs_sachalinensis': 1.0, 'Eriophora_pustulosa': 1.0, 'Acroaspis_sp_IDV6688': 1.0, 'Neoscona_scylla': 1.0, 'Neoscona_subpullata': 1.0, 'Neoscona_theisi': 1.0, 'Neoscona_nautica': 1.0, 'Neoscona_adianta': 1.0, 'Ordgarius_hobsoni': 1.0, 'Ordgarius_sexspinosus': 1.0, 'Cyrtarachne_bufo': 1.0, 'Poecilopachys_australasia': 1.0, 'Hypsosinga_pygmaea': 1.0, 'Larinioides_cornutus': 1.0, 'Nuctenea_umbratica': 1.0, 'Larinia_phthisica': 1.0, 'Lariniaria_argiopiformis': 1.0, 'Microbathyphantes_tateyamaensis': 0.0, 'Neriene_oidedicata': 0.0, 'Neriene_clathrata': 0.0, 'Doenitzius_peniculus': 0.0, 'Doenitzius_pruvus': 0.0, 'Saaristoa_nipponica': 0.0, 'Floronia_bucculenta': 0.0, 'Drapetisca_socialis': 0.0, 'Syedra_oii': 0.0, 'Arcuphantes_tamaensis': 0.0, 'Arcuphantes_uenoi': 0.0, 'Arcuphantes_paiki': 0.0, 'Ryojius_japonicus': 0.0, 'Pseudomicrargus_latitegulatus': 0.0, 'Saitonia_ojiroensis': 0.0, 'Hypselistes_asiaticus': 0.0, 'Baryphymula_kamakuraensis': 0.0, 'Ainerigone_saitoi': 0.0, 'Gnathonarium_exsiccatum': 0.0, 'Ummeliata_osakaensis': 0.0, 'Ambicodamus_IDV6680': 0.0, 'Uloborus_diversus': 0.0, 'Deinopis_sp_IDV6783': 0.0, 'Deinopis_sp_IDV7365': 0.0, 'Desis_marina': 1.0, 'Neoantistea_quelpartensis': 1.0, 'Paratheuma_awasensis': 1.0, 'Pharta_brevipalpus': 1.0, 'Stephanopis_cambridgei': 0.0, 'Oxytate_striatipes': 0.0, 'Lehtinelagia_evanida': 1.0, 'Ozyptila_nongae': 0.0, 'Diaea_subdola': 0.0, 'Ebrechtella_tricuspidata': 0.0, 'Psechrus_IDV5238': 0.0, 'Pardosa_graminea': 0.0, 'Piratula_tanakai': 0.0, 'Zelotes_iriomotensis': 0.0, 'Clubiona_robusta': 0.0, 'Phrurolithus_coreanus': 0.0, 'Helpis_minitabunda': 0.0, 'Stertinius_kumadai': 0.0, 'Neon_minutus': 0.0}
# /Users/calvin/orb-selection/src/odds_ratio_test.py:199: RuntimeWarning: invalid value encountered in log
#   return -np.nansum(np.log(p), axis=0)
# Mean: 0.04, Stddev: 0.96, Count: 7999
# Optimized triple Gaussian parameters: [ 0.4892207  -0.02856574  0.65844888  0.5107793   0.0963324   1.18265067
#   0.6605269   0.69433012]
#
# LAUNCHING PERMUTATION TEST
#
# ** Minimum occupancy set to 49 **
#
# Using 10000 permulation-derived foreground/background
# assignments (from simulated trees) instead of random assignment.
#
# Counting permuted distributions in which statistics
# derived from permulation-derived test groups EXCEED
# the true distribution's statistics (right-tailed)...
# 100%|██████████| 10000/10000 [1:15:45<00:00,  2.20it/s]
# Permutation counter for MEAN (single Gaussian): 3093
#
# Permutation counter for MEAN 1 (triple Gaussian): 1080
#
# Permutation counter for MEAN 2 (triple Gaussian): 3058
#
# Permutation counter for MEAN 3 (triple Gaussian): 5093
#
# Filtering log odds ratio results df for occupancy >= 49, <= 98
# and log odds ratio threshold [-1.53875916  1.53168347]
#
# Filtering for presence of Uloborus_diversus
#
# *********************** RESULTS ***********************
#
# Permutation test with 10000 repetitions for duplication (right-tailed)
# with minimum occupancy *49* and maximum occupancy *no*
# Analysis run on 2026-03-23 at 19:52:02
# Foreground list: /Users/calvin/orb-selection/assets/orbweavers-list.txt
# Gene count file: /Users/calvin/orb-selection/assets/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/assets/N5.tsv
#
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 7999
# Total species: 98
# Foreground count: 44
# Background count: 54
# True mean: 0.035269482343227666
# True standard deviation: 0.9646321954265968
#
# ** PERMUTATION P-VALUES **
#
# Probability that the null is true for MEAN (single Gaussian): 0.3093
# Probability that the null is true for MEAN 1 (triple Gaussian): 0.108
# Probability that the null is true for MEAN 2 (triple Gaussian): 0.3058
# Probability that the null is true for MEAN 3 (triple Gaussian): 0.5093
#
# permuted average mean: -0.0035378484205852174
# permuted average standard deviation: 0.9333482860098411
# User-defined significance threshold: 0.05
# Permutation-derived alpha threshold: [-1.53875916  1.53168347]
#
# Total HOGs with significantly different LORs between
# foreground and background (two-tailed): 917
#
# Total HOGs with significantly different LORs between
# foreground and background (two-tailed, Uloborus_diversus present): 611
#
# *********************** RESULTS ***********************
#
# Permutation test with 10000 repetitions for duplication (right-tailed)
# with minimum occupancy *49* and maximum occupancy *no*
# Analysis run on 2026-03-23 at 19:52:02
# Foreground list: /Users/calvin/orb-selection/assets/orbweavers-list.txt
# Gene count file: /Users/calvin/orb-selection/assets/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/assets/N5.tsv
#
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 7999
# Total species: 98
# Foreground count: 44
# Background count: 54
# True mean: 0.035269482343227666
# True standard deviation: 0.9646321954265968
#
# ** PERMUTATION P-VALUES **
#
# Probability that the null is true for MEAN (single Gaussian): 0.3093
# Probability that the null is true for MEAN 1 (triple Gaussian): 0.108
# Probability that the null is true for MEAN 2 (triple Gaussian): 0.3058
# Probability that the null is true for MEAN 3 (triple Gaussian): 0.5093
#
# permuted average mean: -0.0035378484205852174
# permuted average standard deviation: 0.9333482860098411
# User-defined significance threshold: 0.05
# Permutation-derived alpha threshold: [-1.53875916  1.53168347]
#
# Total HOGs with significantly different LORs between
# foreground and background (two-tailed): 917
#
# Total HOGs with significantly different LORs between
# foreground and background (two-tailed, Uloborus_diversus present): 611
#
# Results files saved to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Mar23/Run2_Dup_RT_49-max_10000x
#
# Files include:
# 	 1. [test]_permutation_results.png: True LORs distribution
# 		vs. average permuted distribution
# 	 2. [test]_permutation_stats_dists.png: Histograms of the
# 		means, standard deviations, and skews of all 10,000
# 		permuted LOR distributions
# 	 3. [test]_results_summary.txt: Text file summarizing results
# 	 4. [test].pkl: Pickle file storing the BoostrapTestResults
# 		instance generated by this analysis
# 	 5. [test]_[species]_fltrd_permutation_hits.csv: Results table
# 		filtered for occupancy, species of interest (if specified),
# 		and surpassing permutation-derived significance thresholds
# 	 6. All odds and log odds ratios (not filtered for occupancy,
# 		species, or significance)
