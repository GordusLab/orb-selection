# %%
import os
import sys

# Resolve repo root whether cwd is repo root, scripts/, or a stage subdirectory.
cwd = os.getcwd()
if os.path.basename(cwd) == "orb-selection":
    repo_root = cwd
elif os.path.basename(os.path.dirname(cwd)) == "orb-selection":
    repo_root = os.path.dirname(cwd)
elif os.path.basename(os.path.dirname(os.path.dirname(cwd))) == "orb-selection":
    repo_root = os.path.dirname(os.path.dirname(cwd))
else:
    repo_root = cwd

src_path = os.path.join(repo_root, "src")
stage04_path = os.path.join(repo_root, "scripts", "04_permulation_loss_dup")
for path in (src_path, stage04_path):
    if path not in sys.path:
        sys.path.insert(0, path)

print(f"Using src path: {src_path}")
print(f"Using stage-04 path: {stage04_path}")

# Import modules
import odds_ratio_test as ort
from id_converter import convert_hogs_to_locs

# %load_ext autoreload
# Out:
# Using src path: /Users/calvin/orb-selection/src
# Using stage-04 path: /Users/calvin/orb-selection/scripts/04_permulation_loss_dup
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Loss

# %%
# %autoreload 2
loss_lt_32_62 = ort.odds_ratio_test(
    test="loss",
    occupancy_threshold=32,
    max_occ=62,
    alternative="less",
    species_of_interest="Uloborus_diversus",
    results_dir=f"results/odds_ratio_test",
    fg_name='orbweavers (only tetragnathids)',
    bg_name='non-orbweavers (no araneids)',
    foreground_list_filename="data/tetragnathids.txt",
    background_list_filename="data/non-orb-weavers-no-araneids.txt",
    permulations_tip_values_csv="data/perms_tip_values_only_tetragnathids.csv",
    save_two_tailed_hits=True,
)
# Out:
# 65 species total, 14 foreground, 51 background
# Mean: -0.72, Stddev: 2.01, Count: 5105
# /Users/calvin/orb-selection/scripts/04_permulation_loss_dup/odds_ratio_test.py:279: RuntimeWarning: invalid value encountered in log
#   return -np.nansum(np.log(p), axis=0)
# Optimized triple Gaussian parameters:
#   weight_1: -0.000
#   mean_1: -0.242
#   stddev_1: 2.552
#   weight_2: 0.791
#   mean_2: -1.316
#   stddev_2: 1.417
#   mean_3: 1.524
#   stddev_3: 2.302
#
# LAUNCHING PERMUTATION TEST
#
# ** Maximum occupancy set to 62 **
# ** Minimum occupancy set to 32 **
#
# Using 10000 permulation-derived foreground/background assignments (from simulated trees) instead
# of random assignment.
# Counting permuted distributions in which statistics derived from permulation-derived test groups
# are SMALLER than the true distribution's statistics...
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %% [markdown]
# ## Duplication

# %%
# %autoreload 2
dup_rt_32_65 = ort.odds_ratio_test(
    test="duplication",
    occupancy_threshold=32,
    alternative="greater",
    species_of_interest="Uloborus_diversus",
    results_dir=f"results/odds_ratio_test",
    fg_name='orbweavers (only tetragnathids)',
    bg_name='non-orbweavers (no araneids)',
    foreground_list_filename="data/tetragnathids.txt",
    background_list_filename="data/non-orb-weavers-no-araneids.txt",
    permulations_tip_values_csv="data/perms_tip_values_only_tetragnathids.csv",
    save_two_tailed_hits=True
)
# Out:
# 84 species total, 30 foreground, 54 background
# Mean: -0.04, Stddev: 1.07, Count: 8063
# /Users/calvin/orb-selection/scripts/04_permulation_loss_dup/odds_ratio_test.py:279: RuntimeWarning: invalid value encountered in log
#   return -np.nansum(np.log(p), axis=0)
# Optimized triple Gaussian parameters:
#   weight_1: 0.401
#   mean_1: -0.560
#   stddev_1: 1.002
#   weight_2: 0.412
#   mean_2: -0.008
#   stddev_2: 0.701
#   mean_3: 1.007
#   stddev_3: 1.120
#
# LAUNCHING PERMUTATION TEST
#
# ** Minimum occupancy set to 42 **
#
# Using 10000 permulation-derived foreground/background assignments (from simulated trees) instead
# of random assignment.
# Counting permuted distributions in which statistics derived from permulation-derived test groups
# EXCEED the true distribution's statistics...
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Permutation counter for MEAN (single Gaussian): 5033
# Permutation counter for MEAN 1 (triple Gaussian): 3309
# Permutation counter for MEAN 2 (triple Gaussian): 6974
# Permutation counter for MEAN 3 (triple Gaussian): 3018
#
# Filtering log odds ratio results df for occupancy >= 42, <= 84 with alternative hypothesis
# 'two-tailed' and log odds ratio threshold [-2.12630468  2.08376219]
#
# Filtering for presence of Uloborus_diversus
#
# *********************** RESULTS ***********************
#
# Permutation test with 10000 repetitions for duplication (alternative = greater) with minimum
# occupancy *42* and maximum occupancy *no*
# Analysis run on 2026-04-07 at 15:44:47
# Foreground list: /Users/calvin/orb-selection/data/orbweavers-list-no-tetragnathids.txt
# Background list: /Users/calvin/orb-selection/data/non-orb-weavers-list.txt
# Gene count file: /Users/calvin/orb-selection/data/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/data/N5.tsv
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 8063
# Total species: 84
# Foreground count: 30
# Background count: 54
# True mean: -0.039
# True standard deviation: 1.074
#
# ** PERMUTATION P-VALUES **
#
# Probability that the null is true for MEAN (single Gaussian): 0.5033
# Probability that the null is true for MEAN 1 (triple Gaussian): 0.3309
# Probability that the null is true for MEAN 2 (triple Gaussian): 0.6974
# Probability that the null is true for MEAN 3 (triple Gaussian): 0.3018
#
# Permuted average mean: -0.02127124465035424
# Permuted average standard deviation: 1.0740163845143993
# User-defined significance threshold: 0.05
# Permutation-derived alpha threshold: [-2.12630468  2.08376219]
#
# Total HOGs with significantly different odds of duplication in foreground and background
# (alternative = two-tailed): 470
# Total HOGs with significantly different odds of duplication in foreground and background
# (alternative = two-tailed, Uloborus_diversus present): 314
# Processing HOGs:   0%|          | 0/314 [00:00<?, ?it/s]
# Results files saved to
# /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr07/Run4_Dup_RT_42-max_10000x
#
# Files include:
# 	 1. [test]_permutation_results.png: True LORs distribution
# 		vs. average permuted distribution
# 	 2. [test]_permutation_stats_dists.png: Histograms of the
# 		means, standard deviations, and skews of all 10,000
# 		permuted LOR distributions
# 	 3. [test]_results_summary.txt: Text file summarizing results
# 	 4. [test].pkl: Pickle file storing the BoostrapTestResults
# 		instance generated by this analysis
# 	 5. [test]_[species]_fltrd_permutation_hits.csv: Results table
# 		filtered for occupancy, species of interest (if specified),
# 		and surpassing permutation-derived significance thresholds
# 	 6. [test]_[species]_fltrd_permutation_hits_locs_desc.csv: Hits with
# 		LOC IDs and descriptions from id_converter. There may be multiple
# 		rows per HOG if there are multiple genes from the U.div. in the HOG.
# 	 7. All odds and log odds ratios (not filtered for occupancy,
# 		species, or significance)
