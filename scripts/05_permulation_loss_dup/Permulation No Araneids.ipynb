# %%
import os
import sys

# Resolve repo root whether cwd is repo root, scripts/, or a stage subdirectory.
cwd = os.getcwd()
if os.path.basename(cwd) == "orb-selection":
    repo_root = cwd
elif os.path.basename(os.path.dirname(cwd)) == "orb-selection":
    repo_root = os.path.dirname(cwd)
elif os.path.basename(os.path.dirname(os.path.dirname(cwd))) == "orb-selection":
    repo_root = os.path.dirname(os.path.dirname(cwd))
else:
    repo_root = cwd

src_path = os.path.join(repo_root, "src")
stage05_path = os.path.join(repo_root, "scripts", "05_permulation_loss_dup")
for path in (src_path, stage05_path):
    if path not in sys.path:
        sys.path.insert(0, path)

print(f"Using src path: {src_path}")
print(f"Using stage-05 path: {stage05_path}")

# Import modules
import odds_ratio_test as ort
from id_converter import convert_hogs_to_locs

# %load_ext autoreload
# Out:
# Using src path: /Users/calvin/orb-selection/src
# Using stage-05 path: /Users/calvin/orb-selection/scripts/05_permulation_loss_dup

# %%
# %autoreload 2
dup_rt_50_98 = ort.odds_ratio_test(
    test="duplication",
    occupancy_threshold=50,
    alternative="greater",
    species_of_interest="Uloborus_diversus",
    results_dir=f"results/odds_ratio_test",
    fg_name='orbweavers',
    bg_name='non-orbweavers',
    foreground_list_filename="data/orbweavers-list-no-araneids.txt",
    background_list_filename="data/non-orb-weavers-no-araneids.txt",
    permulations_tip_values_csv="data/perms_tip_values_no_araneids.csv"
)
# Out:
# 68 species total, 17 foreground, 51 background
# Mean: 0.17, Stddev: 1.00, Count: 5205
# Optimized triple Gaussian parameters:
#   weight_1: 0.575
#   mean_1: 0.147
#   stddev_1: 1.163
#   weight_2: 0.425
#   mean_2: 0.196
#   stddev_2: 0.726
#   mean_3: 1.651
#   stddev_3: 0.674
#
# LAUNCHING PERMUTATION TEST
#
# ** Minimum occupancy set to 50 **
#
# Using 10000 permulation-derived foreground/background assignments (from simulated trees) instead
# of random assignment.
# Counting permuted distributions in which statistics derived from permulation-derived test groups
# EXCEED the true distribution's statistics...
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Permutation counter for MEAN (single Gaussian): 913
# Permutation counter for MEAN 1 (triple Gaussian): 187
# Permutation counter for MEAN 2 (triple Gaussian): 5256
# Permutation counter for MEAN 3 (triple Gaussian): 9
#
# Filtering log odds ratio results df for occupancy >= 50, <= 68 with alternative hypothesis
# 'greater' and log odds ratio threshold [-1.52676871  1.6529203 ]
#
# Filtering for presence of Uloborus_diversus
#
# *********************** RESULTS ***********************
#
# Permutation test with 10000 repetitions for duplication (alternative = greater) with minimum
# occupancy *50* and maximum occupancy *no*
# Analysis run on 2026-04-06 at 18:13:22
# Foreground list: /Users/calvin/orb-selection/data/orbweavers-list-no-araneids.txt
# Background list: /Users/calvin/orb-selection/data/non-orb-weavers-no-araneids.txt
# Gene count file: /Users/calvin/orb-selection/data/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/data/N5.tsv
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 5205
# Total species: 68
# Foreground count: 17
# Background count: 51
# True mean: 0.168
# True standard deviation: 1.001
#
# ** PERMUTATION P-VALUES **
#
# Probability that the null is true for MEAN (single Gaussian): 0.0913
# Probability that the null is true for MEAN 1 (triple Gaussian): 0.0187
# Probability that the null is true for MEAN 2 (triple Gaussian): 0.5256
# Probability that the null is true for MEAN 3 (triple Gaussian): 0.0009
#
# Permuted average mean: 0.06307579600395034
# Permuted average standard deviation: 0.9665568273582062
# User-defined significance threshold: 0.05
# Permutation-derived alpha threshold: [-1.52676871  1.6529203 ]
#
# Total HOGs with significantly greater odds of duplication in foreground than background
# (alternative = greater): 331
# Total HOGs with significantly greater odds of duplication in foreground than background
# (alternative = greater, Uloborus_diversus present): 308
# Processing HOGs:   0%|          | 0/308 [00:00<?, ?it/s]
# Results files saved to
# /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr06/Run1_Dup_RT_50-max_10000x
#
# Files include:
# 	 1. [test]_permutation_results.png: True LORs distribution
# 		vs. average permuted distribution
# 	 2. [test]_permutation_stats_dists.png: Histograms of the
# 		means, standard deviations, and skews of all 10,000
# 		permuted LOR distributions
# 	 3. [test]_results_summary.txt: Text file summarizing results
# 	 4. [test].pkl: Pickle file storing the BoostrapTestResults
# 		instance generated by this analysis
# 	 5. [test]_[species]_fltrd_permutation_hits.csv: Results table
# 		filtered for occupancy, species of interest (if specified),
# 		and surpassing permutation-derived significance thresholds
# 	 6. [test]_[species]_fltrd_permutation_hits_locs_desc.csv: Hits with
# 		LOC IDs and descriptions from id_converter. There may be multiple
# 		rows per HOG if there are multiple genes from the U.div. in the HOG.
# 	 7. All odds and log odds ratios (not filtered for occupancy,
# 		species, or significance)

# %% [markdown]
# ## Loss

# %%
# %autoreload 2
loss_lt_34_65 = ort.odds_ratio_test(
    test="loss",
    occupancy_threshold=34,
    max_occ=65,
    alternative="less",
    species_of_interest="Uloborus_diversus",
    results_dir=f"results/odds_ratio_test",
    fg_name='orbweavers',
    bg_name='non-orbweavers',
    foreground_list_filename="data/orbweavers-list-no-araneids.txt",
    background_list_filename="data/non-orb-weavers-no-araneids.txt",
    permulations_tip_values_csv="data/perms_tip_values_no_araneids.csv",
    save_two_tailed_hits=True,
)
# Out:
# 68 species total, 17 foreground, 51 background
# Mean: -0.38, Stddev: 1.58, Count: 5047
# Optimized triple Gaussian parameters:
#   weight_1: -0.000
#   mean_1: -1.756
#   stddev_1: 1.583
#   weight_2: 0.775
#   mean_2: -0.841
#   stddev_2: 1.137
#   mean_3: 1.205
#   stddev_3: 1.844
#
# LAUNCHING PERMUTATION TEST
#
# ** Maximum occupancy set to 65 **
# ** Minimum occupancy set to 34 **
#
# Using 10000 permulation-derived foreground/background assignments (from simulated trees) instead
# of random assignment.
# Counting permuted distributions in which statistics derived from permulation-derived test groups
# are SMALLER than the true distribution's statistics...
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Permutation counter for MEAN (single Gaussian): 4454
# Permutation counter for MEAN 1 (triple Gaussian): 873
# Permutation counter for MEAN 2 (triple Gaussian): 3553
# Permutation counter for MEAN 3 (triple Gaussian): 3659
#
# Filtering log odds ratio results df for occupancy >= 34, <= 65 with alternative hypothesis
# 'two-tailed' and log odds ratio threshold [-3.44818634  3.12240046]
#
# Filtering for presence of Uloborus_diversus
#
# *********************** RESULTS ***********************
#
# Permutation test with 10000 repetitions for loss (alternative = less) with minimum occupancy
# *34* and maximum occupancy *65*
# Analysis run on 2026-04-07 at 10:43:10
# Foreground list: /Users/calvin/orb-selection/data/orbweavers-list-no-araneids.txt
# Background list: /Users/calvin/orb-selection/data/non-orb-weavers-no-araneids.txt
# Gene count file: /Users/calvin/orb-selection/data/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/data/N5.tsv
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 5047
# Total species: 68
# Foreground count: 17
# Background count: 51
# True mean: -0.379
# True standard deviation: 1.582
#
# ** PERMUTATION P-VALUES **
#
# Probability that the null is true for MEAN (single Gaussian): 0.4454
# Probability that the null is true for MEAN 1 (triple Gaussian): 0.0873
# Probability that the null is true for MEAN 2 (triple Gaussian): 0.3553
# Probability that the null is true for MEAN 3 (triple Gaussian): 0.3659
#
# Permuted average mean: -0.1628929415915902
# Permuted average standard deviation: 1.676200904043641
# User-defined significance threshold: 0.05
# Permutation-derived alpha threshold: [-3.44818634  3.12240046]
#
# Total HOGs with significantly different odds of loss in foreground and background (alternative =
# two-tailed): 227
# Total HOGs with significantly different odds of loss in foreground and background (alternative =
# two-tailed, Uloborus_diversus present): 180
# Processing HOGs:   0%|          | 0/180 [00:00<?, ?it/s]
# Results files saved to
# /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr07/Run1_Loss_LT_34-65_10000x
#
# Files include:
# 	 1. [test]_permutation_results.png: True LORs distribution
# 		vs. average permuted distribution
# 	 2. [test]_permutation_stats_dists.png: Histograms of the
# 		means, standard deviations, and skews of all 10,000
# 		permuted LOR distributions
# 	 3. [test]_results_summary.txt: Text file summarizing results
# 	 4. [test].pkl: Pickle file storing the BoostrapTestResults
# 		instance generated by this analysis
# 	 5. [test]_[species]_fltrd_permutation_hits.csv: Results table
# 		filtered for occupancy, species of interest (if specified),
# 		and surpassing permutation-derived significance thresholds
# 	 6. [test]_[species]_fltrd_permutation_hits_locs_desc.csv: Hits with
# 		LOC IDs and descriptions from id_converter. There may be multiple
# 		rows per HOG if there are multiple genes from the U.div. in the HOG.
# 	 7. All odds and log odds ratios (not filtered for occupancy,
# 		species, or significance)

# %% [markdown]
# ## Duplication

# %%
# %autoreload 2
dup_rt_34_68 = ort.odds_ratio_test(
    test="duplication",
    occupancy_threshold=34,
    alternative="greater",
    species_of_interest="Uloborus_diversus",
    results_dir=f"results/odds_ratio_test",
    fg_name='orbweavers',
    bg_name='non-orbweavers',
    foreground_list_filename="data/orbweavers-list-no-araneids.txt",
    background_list_filename="data/non-orb-weavers-no-araneids.txt",
    permulations_tip_values_csv="data/perms_tip_values_no_araneids.csv",
    save_two_tailed_hits=True
)
# Out:
# 68 species total, 17 foreground, 51 background
# Mean: 0.24, Stddev: 1.08, Count: 7911
# Optimized triple Gaussian parameters:
#   weight_1: 0.461
#   mean_1: 0.255
#   stddev_1: 0.840
#   weight_2: 0.531
#   mean_2: 0.217
#   stddev_2: 1.242
#   mean_3: 1.467
#   stddev_3: 0.991
#
# LAUNCHING PERMUTATION TEST
#
# ** Minimum occupancy set to 34 **
#
# Using 10000 permulation-derived foreground/background assignments (from simulated trees) instead
# of random assignment.
# Counting permuted distributions in which statistics derived from permulation-derived test groups
# EXCEED the true distribution's statistics...
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Permutation counter for MEAN (single Gaussian): 879
# Permutation counter for MEAN 1 (triple Gaussian): 305
# Permutation counter for MEAN 2 (triple Gaussian): 4776
# Permutation counter for MEAN 3 (triple Gaussian): 3373
#
# Filtering log odds ratio results df for occupancy >= 34, <= 68 with alternative hypothesis
# 'two-tailed' and log odds ratio threshold [-2.03848318  2.17641699]
#
# Filtering for presence of Uloborus_diversus
#
# *********************** RESULTS ***********************
#
# Permutation test with 10000 repetitions for duplication (alternative = greater) with minimum
# occupancy *34* and maximum occupancy *no*
# Analysis run on 2026-04-07 at 11:45:29
# Foreground list: /Users/calvin/orb-selection/data/orbweavers-list-no-araneids.txt
# Background list: /Users/calvin/orb-selection/data/non-orb-weavers-no-araneids.txt
# Gene count file: /Users/calvin/orb-selection/data/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/data/N5.tsv
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 7911
# Total species: 68
# Foreground count: 17
# Background count: 51
# True mean: 0.244
# True standard deviation: 1.080
#
# ** PERMUTATION P-VALUES **
#
# Probability that the null is true for MEAN (single Gaussian): 0.0879
# Probability that the null is true for MEAN 1 (triple Gaussian): 0.0305
# Probability that the null is true for MEAN 2 (triple Gaussian): 0.4776
# Probability that the null is true for MEAN 3 (triple Gaussian): 0.3373
#
# Permuted average mean: 0.06896690372600842
# Permuted average standard deviation: 1.0752493913392407
# User-defined significance threshold: 0.05
# Permutation-derived alpha threshold: [-2.03848318  2.17641699]
#
# Total HOGs with significantly different odds of duplication in foreground and background
# (alternative = two-tailed): 444
# Total HOGs with significantly different odds of duplication in foreground and background
# (alternative = two-tailed, Uloborus_diversus present): 323
# Processing HOGs:   0%|          | 0/323 [00:00<?, ?it/s]
# Results files saved to
# /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr07/Run2_Dup_RT_34-max_10000x
#
# Files include:
# 	 1. [test]_permutation_results.png: True LORs distribution
# 		vs. average permuted distribution
# 	 2. [test]_permutation_stats_dists.png: Histograms of the
# 		means, standard deviations, and skews of all 10,000
# 		permuted LOR distributions
# 	 3. [test]_results_summary.txt: Text file summarizing results
# 	 4. [test].pkl: Pickle file storing the BoostrapTestResults
# 		instance generated by this analysis
# 	 5. [test]_[species]_fltrd_permutation_hits.csv: Results table
# 		filtered for occupancy, species of interest (if specified),
# 		and surpassing permutation-derived significance thresholds
# 	 6. [test]_[species]_fltrd_permutation_hits_locs_desc.csv: Hits with
# 		LOC IDs and descriptions from id_converter. There may be multiple
# 		rows per HOG if there are multiple genes from the U.div. in the HOG.
# 	 7. All odds and log odds ratios (not filtered for occupancy,
# 		species, or significance)
