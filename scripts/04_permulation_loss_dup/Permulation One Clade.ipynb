# %%
import os
import sys

# Resolve repo root whether cwd is repo root, scripts/, or a stage subdirectory.
cwd = os.getcwd()
if os.path.basename(cwd) == "orb-selection":
    repo_root = cwd
elif os.path.basename(os.path.dirname(cwd)) == "orb-selection":
    repo_root = os.path.dirname(cwd)
elif os.path.basename(os.path.dirname(os.path.dirname(cwd))) == "orb-selection":
    repo_root = os.path.dirname(os.path.dirname(cwd))
else:
    repo_root = cwd

src_path = os.path.join(repo_root, "src")
stage05_path = os.path.join(repo_root, "scripts", "05_permulation_loss_dup")
for path in (src_path, stage05_path):
    if path not in sys.path:
        sys.path.insert(0, path)

print(f"Using src path: {src_path}")
print(f"Using stage-05 path: {stage05_path}")

# Import modules
import odds_ratio_test as ort
from id_converter import convert_hogs_to_locs

# %load_ext autoreload
# Out:
# Using src path: /Users/calvin/orb-selection/src
# Using stage-05 path: /Users/calvin/orb-selection/scripts/05_permulation_loss_dup
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
ort.odds_ratio_test(
    min_occ=30,
    max_occ=71,
    results_dir=f"results/odds_ratio_test",
    fg_name='orbweavers (only araneids)',
    bg_name='non-orbweavers',
    foreground_list_filename="data/araneids-orbweavers.txt",
    background_list_filename="data/non-orb-weavers-list.txt",
    permulations_tip_values_csv="data/perms_tip_values_only_araneids.csv",
    dir_suffix='only_ara',
)
# Out:
# 81 species total, 27 foreground, 54 background
# Log odds ratios of LOSS:
#  Mean: -1.12, Stddev: 2.44, Count of HOGs: 6459
# Log odds ratios of DUPLICATION:
#  Mean: 0.04, Stddev: 1.36, Count of HOGs: 10539
#
# LAUNCHING PERMULATION TEST
#
# ** Maximum occupancy set to 71 for loss test **
# ** Minimum occupancy set to 30 **
#
# Using 10000 permulation-derived foreground/background assignments.
# 100%|██████████| 10000/10000 [05:26<00:00, 30.61it/s]
# Permulation counter for MEANS:
#  Loss: 2045, Duplication: 6762
# *********************** RESULTS ***********************
#
# Permulation test with 10000 repetitions
# Minimum occupancy: 30; max occupancy (loss): 71
# Analysis run on 2026-04-16 at 16:05:05
# Foreground list: /Users/calvin/orb-selection/data/araneids-orbweavers.txt
# Background list: /Users/calvin/orb-selection/data/non-orb-weavers-list.txt
# Gene count file: /Users/calvin/orb-selection/data/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/data/N5.tsv
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 6459 (loss), 10539 (duplication)
# Total species: 81
# Foreground count: 27
# Background count: 54
# True mean, loss: -1.119
# True standard deviation, loss: 2.437
# True mean, duplication: 0.039
# True standard deviation, duplication: 1.364
#
# ** Permulation P-VALUES **
#
# Probability that the null is true for MEAN, loss (alt=less): 0.204
# Probability that the null is true for MEAN, duplication (alt=greater): 0.676
#
# Permulated average mean, loss: -0.275
# Permulated average standard deviation, loss: 1.987
# Permulated average mean, duplication: 0.031
# Permulated average standard deviation, duplication: 1.239
# User-defined significance threshold: 0.05
# Permulation-derived alpha threshold, loss: [-4.169, 3.619]
# Permulation-derived alpha threshold, duplication: [-2.396, 2.458]
#
# Significant HOGs (all): 4388
#   - loss_fg: 365
#   - loss_bg: 816
#   - dup_fg: 730
#   - dup_bg: 3089
# Wrote 222 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run4_occ_30-71_10000x_only_ara/loc_lists/loss_bg_sig_locs.txt
# Wrote 371 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run4_occ_30-71_10000x_only_ara/loc_lists/dup_fg_sig_locs.txt
# Wrote 47 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run4_occ_30-71_10000x_only_ara/loc_lists/loss_bg_sig_locs_avg_ci.txt
# Wrote 94 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run4_occ_30-71_10000x_only_ara/loc_lists/dup_fg_sig_locs_avg_ci.txt
# Generating universe LOCs...
# Wrote 3102 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run4_occ_30-71_10000x_only_ara/loc_lists/loss_universe_locs.txt
# Wrote 6918 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run4_occ_30-71_10000x_only_ara/loc_lists/dup_universe_locs.txt
# Results files saved.
# Directory: results/odds_ratio_test/Results_Apr16/Run4_occ_30-71_10000x_only_ara
#
# Files include:
#   - results_all.csv: all HOG odds/log-odds and p-values
#   - fltrd_hits.csv: significant hits after occupancy/p-value filters
#   - results_summary.txt: text summary of run settings and statistics
#   - loc_lists/: LOC exports for hits and universes
#     - *_sig_locs.txt: hit LOC lists
#     - *_sig_locs_perm_pval.txt: hit LOC lists filtered by permulation p-values
#     - loss_universe_locs.txt / dup_universe_locs.txt: universe LOC lists
#   - loss_stats_dists.png: permulated mean/stddev histograms for loss
#   - dup_stats_dists.png: permulated mean/stddev histograms for duplication
#   - loss_results.png: loss LOR true distribution vs permulated average
#   - dup_results.png: duplication LOR true distribution vs permulated average
#   - results.pkl: full results object (only when save_pickle=True)
# PermulationTestResults(true_odds=OddsRatioResults(genecount_csv=/Users/calvin/orb-selection/data/N5.GeneCount.tsv, hog_node_genes_tsv=/Users/calvin/orb-selection/data/N5.tsv, foreground_list_filename=/Users/calvin/orb-selection/data/araneids-orbweavers.txt, background_list_filename=/Users/calvin/orb-selection/data/non-orb-weavers-list.txt), min_occ=30, permulation_reps=10000)

# %%
# %autoreload 2
ort.odds_ratio_test(
    min_occ=30,
    max_occ=55,
    results_dir=f"results/odds_ratio_test",
    fg_name='orbweavers (only tetragnathids)',
    bg_name='non-orbweavers (no araneids)',
    foreground_list_filename="data/tetragnathids.txt",
    background_list_filename="data/non-orb-weavers-no-araneids.txt",
    permulations_tip_values_csv="data/perms_tip_values_only_tetragnathids.csv",
    dir_suffix='only_tet'
)
# Out:
# 65 species total, 14 foreground, 51 background
# Log odds ratios of LOSS:
#  Mean: -0.71, Stddev: 2.28, Count of HOGs: 4247
# Log odds ratios of DUPLICATION:
#  Mean: 0.26, Stddev: 1.23, Count of HOGs: 8532
#
# LAUNCHING PERMULATION TEST
#
# ** Maximum occupancy set to 55 for loss test **
# ** Minimum occupancy set to 30 **
#
# Using 10000 permulation-derived foreground/background assignments.
# 100%|██████████| 10000/10000 [05:32<00:00, 30.04it/s]
# Permulation counter for MEANS:
#  Loss: 1545, Duplication: 1000
# *********************** RESULTS ***********************
#
# Permulation test with 10000 repetitions
# Minimum occupancy: 30; max occupancy (loss): 55
# Analysis run on 2026-04-16 at 16:11:04
# Foreground list: /Users/calvin/orb-selection/data/tetragnathids.txt
# Background list: /Users/calvin/orb-selection/data/non-orb-weavers-no-araneids.txt
# Gene count file: /Users/calvin/orb-selection/data/N5.GeneCount.tsv
# Hierarchical orthogroup file: /Users/calvin/orb-selection/data/N5.tsv
# Total number of HOGs in node: 107986
# Total number of HOGs within occupancy threshold: 4247 (loss), 8532 (duplication)
# Total species: 65
# Foreground count: 14
# Background count: 51
# True mean, loss: -0.714
# True standard deviation, loss: 2.276
# True mean, duplication: 0.257
# True standard deviation, duplication: 1.229
#
# ** Permulation P-VALUES **
#
# Probability that the null is true for MEAN, loss (alt=less): 0.154
# Probability that the null is true for MEAN, duplication (alt=greater): 0.100
#
# Permulated average mean, loss: -0.567
# Permulated average standard deviation, loss: 2.082
# Permulated average mean, duplication: 0.217
# Permulated average standard deviation, duplication: 1.173
# User-defined significance threshold: 0.05
# Permulation-derived alpha threshold, loss: [-4.647, 3.513]
# Permulation-derived alpha threshold, duplication: [-2.083, 2.517]
#
# Significant HOGs (all): 2698
#   - loss_fg: 515
#   - loss_bg: 762
#   - dup_fg: 1068
#   - dup_bg: 719
# Wrote 416 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run5_occ_30-55_10000x_only_tet/loc_lists/loss_bg_sig_locs.txt
# Wrote 750 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run5_occ_30-55_10000x_only_tet/loc_lists/dup_fg_sig_locs.txt
# Wrote 0 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run5_occ_30-55_10000x_only_tet/loc_lists/loss_bg_sig_locs_avg_ci.txt
# Wrote 132 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run5_occ_30-55_10000x_only_tet/loc_lists/dup_fg_sig_locs_avg_ci.txt
# Generating universe LOCs...
# Wrote 2452 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run5_occ_30-55_10000x_only_tet/loc_lists/loss_universe_locs.txt
# Wrote 6478 items to /Users/calvin/orb-selection/results/odds_ratio_test/Results_Apr16/Run5_occ_30-55_10000x_only_tet/loc_lists/dup_universe_locs.txt
# Results files saved.
# Directory: results/odds_ratio_test/Results_Apr16/Run5_occ_30-55_10000x_only_tet
#
# Files include:
#   - results_all.csv: all HOG odds/log-odds and p-values
#   - fltrd_hits.csv: significant hits after occupancy/p-value filters
#   - results_summary.txt: text summary of run settings and statistics
#   - loc_lists/: LOC exports for hits and universes
#     - *_sig_locs.txt: hit LOC lists
#     - *_sig_locs_perm_pval.txt: hit LOC lists filtered by permulation p-values
#     - loss_universe_locs.txt / dup_universe_locs.txt: universe LOC lists
#   - loss_stats_dists.png: permulated mean/stddev histograms for loss
#   - dup_stats_dists.png: permulated mean/stddev histograms for duplication
#   - loss_results.png: loss LOR true distribution vs permulated average
#   - dup_results.png: duplication LOR true distribution vs permulated average
#   - results.pkl: full results object (only when save_pickle=True)
# PermulationTestResults(true_odds=OddsRatioResults(genecount_csv=/Users/calvin/orb-selection/data/N5.GeneCount.tsv, hog_node_genes_tsv=/Users/calvin/orb-selection/data/N5.tsv, foreground_list_filename=/Users/calvin/orb-selection/data/tetragnathids.txt, background_list_filename=/Users/calvin/orb-selection/data/non-orb-weavers-no-araneids.txt), min_occ=30, permulation_reps=10000)
