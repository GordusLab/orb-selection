# %% [markdown]
# # Figure 4 Log Odds Ratio Test Plots

# %%
import sys
import os
import matplotlib.pyplot as plt

# Ensure the src directory is in the Python path
scripts = os.path.abspath('')
src_path = os.path.abspath(os.path.join(scripts, '..', 'src'))
if src_path not in sys.path:
    sys.path.append(src_path)

from odds_ratio_test import BootstrapTestResults

ort_results = os.path.join(scripts, '..', 'results', 'odds_ratio_test', 'occ_50/')
figure5 = os.path.join(scripts, "..", "figures/figure_5/")

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Load bootstrap results

# %%
loss_50_95_bsr = BootstrapTestResults.load_from_pickle(str(ort_results + "loss_LT/loss_occ50-95_LT.pkl"))
dup_50_98_bsr = BootstrapTestResults.load_from_pickle(str(ort_results + "duplication_RT/duplication_occ50-98_RT.pkl"))

# %%
loss_50_95_bsr.ci_av
# Out:
# array([-1.38433089,  1.38801583])

# %%
dup_50_98_bsr.ci_av
# Out:
# array([-1.52977679,  1.53390291])

# %%
fig4a, ax = loss_50_95_bsr.plot_bootstrap_results(
    fg_name="orbweavers",
    bg_name="non-orbweavers",
    gaussfit_color="salmon",
    avbootstrap_color="steelblue",
    hist_color="#9569B7",
    thresholds_color="black",
    title=False
)

# plt.savefig(str(figure5 + "loss_50_95_bootstrap.png"), dpi=300, bbox_inches="tight", transparent=True)
# Out:
# #9569B7

# %%
dup_50_98_bsr.plot_bootstrap_results(
    fg_name="orbweavers",
    bg_name="non-orbweavers",
    gaussfit_color="salmon",
    avbootstrap_color="steelblue",
    hist_color="#9569B7",
    thresholds_color="black",
    title=False
)

# plt.savefig(str(figure5 + "dup_50_98_bootstrap.png"), dpi=300, bbox_inches="tight", transparent=True)
# Out:
# #9569B7
# (<Figure size 600x500 with 1 Axes>,
#  <Axes: xlabel='Log odds ratio', ylabel='Density'>)

# %%
lossfigs, lossaxs = loss_50_95_bsr.plot_bootstrap_results_layered(
    fg_name="orbweavers",
    bg_name="non-orbweavers",
    gaussfit_color="salmon",
    avbootstrap_color="steelblue",
    hist_color="#9569B7",
    thresholds_color="black",
    title=False
)

for i, fig in enumerate(lossfigs):
    fig.savefig(str(figure5) + "loss_50_95_bootstrap_layered" + str(i) + ".png", dpi=300, bbox_inches="tight", transparent=False)

# %%
dupfigs, dupaxs = dup_50_98_bsr.plot_bootstrap_results_layered(
    fg_name="orbweavers",
    bg_name="non-orbweavers",
    gaussfit_color="salmon",
    avbootstrap_color="steelblue",
    hist_color="#9569B7",
    thresholds_color="black",
    title=False
)

for i, fig in enumerate(dupfigs):
    fig.savefig(str(figure5) + "dup_50_98_bootstrap_layered" + str(i) + ".png", dpi=300, bbox_inches="tight", transparent=False)
